# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/olist_orders_dataset.csv", parse_dates=["order_purchase_timestamp",
                                                                  "order_approved_at",
                                                                  "order_delivered_carrier_date",
                                                                  "order_delivered_customer_date",
                                                                  "order_estimated_delivery_date"
                                                                 ]).dropna(how="all")
df.info()
df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# ...

# %%
approval_df = df[df.order_approved_at.notna()].copy()
approval_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99281 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99281 non-null  object
#  1   customer_id                    99281 non-null  object
#  2   order_status                   99281 non-null  object
#  3   order_purchase_timestamp       99281 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97644 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96462 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99281 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.8+ MB

# %%
#Doba schválením objednávky (v minutách a hodinách)
approval_df["approval_time_minutes"] = (
    ((approval_df.order_approved_at - approval_df.order_purchase_timestamp).dt.total_seconds() / 60).astype(int)
)
approval_df["approval_time_hours"] = (
    ((approval_df.order_approved_at - approval_df.order_purchase_timestamp).dt.total_seconds() / 3600).round(2)
)
approval_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
approval_df.approval_time_minutes.describe()
# Out:
# count     99281.000000
# mean        624.660801
# std        1562.275891
# min           0.000000
# 25%          12.000000
# 50%          20.000000
# 75%         874.000000
# max      270550.000000
# Name: approval_time_minutes, dtype: float64

# %%
#Základní popis
approval_df.approval_time_minutes.mean().round() #624 min
approval_df.approval_time_minutes.median() #20 min
approval_df.approval_time_minutes.max() #27 0550 min = 187 days
# Out:
# 270550

# %%
#Kategorie doby schvalování objednávek
approval_df["approval_category"] = (
    np.where(approval_df.approval_time_minutes <= 30, "0–30 min",
    np.where(approval_df.approval_time_minutes <= 120, "31–120 min",
    np.where(approval_df.approval_time_minutes <= 1440, "121–1440 min",
    "1440+ min"
            ))))
approval_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
#Df s absolutním a relativním přehledem doby schvalování objednávek

categories = ["0–30 min", "31–120 min", "121–1440 min", "1440+ min"]

approval_category_counts = approval_df.approval_category.value_counts()
approval_category_pct = ((approval_category_counts / approval_category_counts.sum()) *100).round(1)

summary_df = pd.DataFrame(data={
    "Counts": approval_category_counts,
    "Percentage": approval_category_pct
}, index=categories)
summary_df
# Out:
#               Counts  Percentage
# 0–30 min       57856        58.3
# 31–120 min      8930         9.0
# 121–1440 min   15168        15.3
# 1440+ min      17327        17.5

# %%
#Histogram

bins = [0, 0.5, 2, 24, np.inf]
counts, bins = np.histogram(approval_df["approval_time_hours"], bins=bins)

x_labels = [
    "0–30 min",     # 0–0.5 h
    "31–120 min",   # 0.5–2 h
    "2–24 h",
    "24+ h"
]

plt.figure(figsize=(8, 4))
plt.bar(x_labels, counts, width=0.6)
plt.title("Order Approval Time Distribution")
plt.xlabel("Approval time")
plt.ylabel("Number of orders")
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
